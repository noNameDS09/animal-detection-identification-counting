# %% [markdown]
# ### Installing YOLO

# %%
# !pip install ultralytics

# %%
import os

print("Train images:", len(os.listdir("../../data/dataset/v1_4000_images/train/images")))
print("Val images:", len(os.listdir("../../data/dataset/v1_4000_images/val/images")))
print("Test images:", len(os.listdir("../../data/dataset/v1_4000_images/test/images")))
# Out:
# Train images: 1400
# Val images: 400
# Test images: 200

# %%
from ultralytics import YOLO

model = YOLO("../models/trained/best.pt")
print(model.names)
# Out:
# {0: 'Bear', 1: 'Deer', 2: 'Elephant', 3: 'Monkey', 4: 'Tiger'}

# %% [markdown]
# ### Base Model Evaluation

# %%
# !yolo detect val model=yolov8n.pt data=D:\TE\Internship\code\data\dataset\v1_4000_images\dataset.yaml imgsz=640
# Out:
# Ultralytics 8.4.15  Python-3.10.8 torch-2.10.0+cpu CPU (13th Gen Intel Core i5-13420H)
# YOLOv8n summary (fused): 72 layers, 3,151,904 parameters, 0 gradients, 8.7 GFLOPs
#
# ...
# val: Fast image access  (ping: 0.10.1 ms, read: 50.341.6 MB/s, size: 400.6 KB)
#
# val: Scanning D:\TE\Internship\code\data\dataset\val\labels... 28 images, 0 backgrounds, 0 corrupt: 7% ╸─────────── 28/400 83.4it/s 0.1s<4.5s
# val: Scanning D:\TE\Internship\code\data\dataset\val\labels... 81 images, 0 backgrounds, 0 corrupt: 20% ━━────────── 81/400 209.8it/s 0.2s<1.5s
# val: Scanning D:\TE\Internship\code\data\dataset\val\labels... 133 images, 0 backgrounds, 0 corrupt: 33% ━━━╸──────── 133/400 295.8it/s 0.3s<0.9s
# val: Scanning D:\TE\Internship\code\data\dataset\val\labels... 187 images, 0 backgrounds, 0 corrupt: 47% ━━━━━╸────── 187/400 363.9it/s 0.4s<0.6s
# val: Scanning D:\TE\Internship\code\data\dataset\val\labels... 239 images, 0 backgrounds, 0 corrupt: 60% ━━━━━━━───── 239/400 410.5it/s 0.5s<0.4s
# ...

# %% [markdown]
# ## Baseline Validation Results (Pretrained YOLOv8n)
#
# | Metric      | Value  |
# |------------|--------|
# | Precision  | 0.0346 |
# | Recall     | 0.122  |
# | mAP50      | 0.0203 |
# | mAP50-95   | 0.0146 |
#
# ## Per-Class mAP50 (COCO Predictions)
#
# | Class       | mAP50  |
# |-------------|--------|
# | person      | 0.0101 |
# | bicycle     | 0.0358 |
# | car         | 0.00584 |
# | motorcycle  | 0.0202 |
# | airplane    | 0.0297 |

# %% [markdown]
# __________________________
